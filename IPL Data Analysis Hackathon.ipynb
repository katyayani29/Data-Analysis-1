# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\KATYAYANI\Downloads\matches.csv")

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
data["season"].max()
# Out:
# 2019

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
#2.The column which has the most missing values according to the data is:

data["umpire3"].isna().sum()
# Out:
# 637

# %%
data["city"].isna().sum()
# Out:
# 7

# %%
#3. City which hosted most number of seasons according to the data is
data["city"].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
#5) Maximum wins by Mumbai Indians in 2011 are
data.loc[(data["season"]==2011) & (data["winner"]=="Mumbai Indians"),["season","winner"]]
# Out:
#      season          winner
# 237    2011  Mumbai Indians
# 241    2011  Mumbai Indians
# 253    2011  Mumbai Indians
# 256    2011  Mumbai Indians
# 259    2011  Mumbai Indians
# 272    2011  Mumbai Indians
# 276    2011  Mumbai Indians
# 281    2011  Mumbai Indians
# 302    2011  Mumbai Indians
# 304    2011  Mumbai Indians

# %%
#7What is the percentage of getting bat and field in feature 'toss_descision'?

decision_percentage = data['toss_decision'].value_counts(normalize=True) * 100
decision_percentage
# Out:
# field    61.243386
# bat      38.756614
# Name: toss_decision, dtype: float64

# %%
#8)Which statement holds true
field_wins = data[data['toss_decision'] == 'field']
field_wins_by_year = field_wins.groupby('season')['winner'].count()
field_wins_by_year
# Out:
# season
# 2008    32
# 2009    22
# 2010    21
# 2011    48
# 2012    37
# 2013    31
# 2014    41
# 2015    32
# 2016    49
# 2017    48
# 2018    50
# 2019    49
# Name: winner, dtype: int64

# %%
wickets_by_bowler = data[data['win_by_wickets'].notnull()].groupby('player_of_match')['win_by_wickets'].count()
wickets_by_bowler
# Out:
# player_of_match
# A Chandila            1
# A Joseph              1
# A Kumble              3
# A Mishra             11
# A Nehra               6
#                      ..
# Washington Sundar     1
# YK Pathan            16
# YS Chahal             1
# Yuvraj Singh          5
# Z Khan                1
# Name: win_by_wickets, Length: 226, dtype: int64

# %%
#15.Which venue has hosted most number of IPL matches?

venue_match_counts = data.groupby('venue')['id'].count()
most_matches_venue = venue_match_counts.idxmax()
print("Venue that has hosted the most number of IPL matches:", most_matches_venue)
# Out:
# Venue that has hosted the most number of IPL matches: Eden Gardens

# %%
data1=pd.read_csv(r"C:\Users\KATYAYANI\Downloads\deliveries.csv")

# %% [markdown]
# data1

# %%
data1
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
data1["bye_runs"].value_counts()
# Out:
# 0    178598
# 1       324
# 4       123
# 2        31
# 3         2
# Name: bye_runs, dtype: int64

# %%
data1.rename(columns={'match_id': 'id'}, inplace=True)
data1=data.merge(data1,how="inner",on=["id"])

# %%
#11. In 2019 which batsman scored highest number of runs by hitting 6's and 4's?
data1.loc[(data1["season"]==2019) & (data1["batsman"]=="CH Gayle") & ((data1["bye_runs"]==6) | (data1["bye_runs"]==4))]
# Out:
#            id  season    city      date            team1             team2  \
# 165550  11140    2019  Jaipur  25/03/19  Kings XI Punjab  Rajasthan Royals
# 172315  11323    2019  Mohali  16/04/19  Kings XI Punjab  Rajasthan Royals
#
#              toss_winner toss_decision  result  dl_applied  ... bye_runs  \
# 165550  Rajasthan Royals         field  normal           0  ...        4
# 172315  Rajasthan Royals         field  normal           0  ...        4
#
#         legbye_runs  noball_runs penalty_runs batsman_runs extra_runs  \
# 165550            0            0            0            4          4
# 172315            0            0            0            4          4
#
#        total_runs player_dismissed  dismissal_kind fielder
# 165550          8              NaN             NaN     NaN
# 172315          8              NaN             NaN     NaN
#
# [2 rows x 38 columns]

# %%
#12. Most number of wickets taken by a bowler is
data1.loc[(data1["dismissal_kind"]=="hit wicket") & (data1["bowler"]=="Harbhajan Singh"),["bowler","dismissal_kind"]]
# Out:
#                 bowler dismissal_kind
# 86635  Harbhajan Singh     hit wicket

# %%
#14.  Bowlers with maximum number of extras:
data1.loc[data1["bowler"]=="P Kumar","extra_runs"].sum()
# Out:
# 236

# %%
#15.Which venue has hosted most number of IPL matches?

venue_match_counts = data.groupby('venue')['id'].count()
most_matches_venue = venue_match_counts.idxmax()
print("Venue that has hosted the most number of IPL matches:", most_matches_venue)
# Out:
# Venue that has hosted the most number of IPL matches: Eden Gardens

# %%
#16. In 2017 when sunrisers hyderabad clashed against Royal Challengers Bangalore which team player won player of the match?
data1.loc[(data1["team1"]=="Sunrisers Hyderabad") & (data1["team2"]=="Royal Challengers Bangalore") & (data1["season"]==2017),['player_of_match']].value_counts()
# Out:
# player_of_match
# Yuvraj Singh       248
# dtype: int64

# %%
#17. Across seasons who are the top three batsman's with most number of run out?
data1.loc[(data1["batsman"]=="MS Dhoni") & (data1["dismissal_kind"]=="run out"),["batsman"]].count()
# Out:
# batsman    21
# dtype: int64

# %%
#18. What are the total runs scored by V Kohli when the bowler was JJ Burmah
data1.loc[(data1["bowler"]=="JJ Bumrah") & (data1["batsman"]=="V Kohli"),["total_runs"]].sum()
# Out:
# total_runs    114
# dtype: int64
