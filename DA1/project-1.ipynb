# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd
import sys
import squarify as sq
import unicodedata

# %%
data=pd.read_csv(r"C:\Users\KATYAYANI\Downloads\autos.csv",encoding_errors="replace")

# %%
data
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
data1=data.copy()

# %%
data1
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
data1.shape
# Out:
# (371528, 20)

# %%
#1.Perform general Data analysis
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
data1.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# ...

# %%
data1=data1.drop_duplicates()

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data1=data1.fillna("Not mentioned")

# %%
#2.Can you tell me the Distribution of Vehicles based on Year of Registration with the help of a plot

pd.crosstab(index=data1["vehicleType"], columns=data1.loc[(data1["yearOfRegistration"]<=2023), "yearOfRegistration"])
# Out:
# yearOfRegistration  1000  1001  1039  1111  1200  1234  1253  1255  1300  \
# vehicleType
# Not mentioned         38     1     1     4     1     4     1     1     2
# andere                 0     0     0     0     0     0     0     0     0
# bus                    0     0     0     0     0     0     0     0     0
# cabrio                 0     0     0     0     0     0     0     0     0
# coupe                  0     0     0     0     0     0     0     0     0
# kleinwagen             0     0     0     0     0     0     0     0     0
# kombi                  0     0     0     0     0     0     0     0     0
# limousine              0     0     0     0     0     0     0     0     0
# suv                    0     0     0     0     0     0     0     0     0
#
# yearOfRegistration  1400  ...  2010  2011  2012  2013  2014  2015  2016  \
# vehicleType               ...
# Not mentioned          1  ...   174   167    92    87    76   218  9438
# ...

# %%
data1["yearOfRegistration"].unique()
# Out:
# array([1993, 2011, 2004, 2001, 2008, 1995, 1980, 2014, 1998, 2005, 1910,
#        2016, 2007, 2009, 2002, 2018, 1997, 1990, 2017, 1981, 2003, 1994,
#        1991, 1984, 2006, 1999, 2012, 2010, 2000, 1992, 2013, 1996, 1985,
#        1989, 2015, 1968, 1982, 1976, 1983, 1959, 1973, 1111, 1969, 1971,
#        1987, 1986, 1988, 1967, 1970, 1965, 1945, 1925, 1974, 1979, 1955,
#        1978, 1972, 1977, 1961, 1963, 1964, 1960, 1966, 1975, 1937, 1936,
#        5000, 1954, 1958, 9999, 1956, 3200, 1000, 1933, 1941, 1962, 8888,
#        1500, 2200, 4100, 1929, 1951, 1957, 1940, 3000, 2066, 1949, 2019,
#        1800, 1953, 1935, 1234, 8000, 5300, 9000, 2900, 6000, 5900, 5911,
#        1400, 1950, 4000, 1948, 1952, 1200, 8500, 1932, 1255, 1927, 1923,
#        1931, 3700, 3800, 4800, 1942, 7000, 1911, 6500, 2290, 2500, 1930,
#        1001, 6200, 9450, 1944, 1943, 1947, 1934, 1938, 1688, 2800, 1253,
#        1928, 7500, 1919, 5555, 7777, 5600, 1600, 1939, 2222, 1039, 9996,
# ...

# %%
plt.figure(figsize=(12, 6))
plt.hist(data['yearOfRegistration'], bins=20, edgecolor='k')
plt.title("Distribution of Vehicles Based on Year of Registration")
plt.xlabel("Year of Registration")
plt.ylabel("Number of Vehicles")
plt.show()

# %%
# 3) Create a plot based on the Variation of the price range by the vehicle type

r=pd.pivot_table(data1, index="vehicleType", values="price", aggfunc="mean")
r
# Out:
#                        price
# vehicleType
# Not mentioned   20137.725263
# andere         677328.957700
# bus             10302.742956
# cabrio          15066.444013
# coupe           25964.071214
# kleinwagen       5694.287796
# kombi            7741.302399
# limousine       11116.186404
# suv             13242.822397

# %%
r.values
# Out:
# array([[ 20137.72526341],
#        [677328.95770033],
#        [ 10302.74295553],
#        [ 15066.44401258],
#        [ 25964.07121443],
#        [  5694.28779586],
#        [  7741.30239924],
#        [ 11116.18640374],
#        [ 13242.8223975 ]])

# %%
sns.barplot(data=data1,x="vehicleType", y="price")
plt.title("Variation of the price range by the vehicle type\n")
plt.xticks(rotation=90)
plt.show()

# %%
# 4) Find out Total count of vehicles by type available on ebay for sale.As well as create a visualization for the client

data1["vehicleType"].value_counts()
# Out:
# limousine        95894
# kleinwagen       80022
# kombi            67563
# Not mentioned    37869
# bus              30201
# cabrio           22898
# coupe            19013
# suv              14707
# andere            3357
# Name: vehicleType, dtype: int64

# %%
sns.countplot(data=data1, x="vehicleType")
plt.title("Total count of vehicles by type available on ebay for sale\n")
plt.xticks(rotation=90)
plt.show()

# %%
# 5) Is there any relationship between dollar_price and kilometer? 
data1[["price", "kilometer"]].corr(method="pearson")
# Out:
#               price  kilometer
# price      1.000000  -0.000635
# kilometer -0.000635   1.000000

# %%
sns.heatmap(data1[["price", "kilometer"]].corr(method="pearson"), annot=True)
plt.title("Relationship between dollar_price and kilometer\n")
plt.show()
